# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
segmentation=pd.read_csv('../Data/challenge-2018-train-vrd.csv')
segmentation.head()
# Out:
#             ImageID  LabelName1 LabelName2    XMin1     XMax1     YMin1  \
# 0  fe58ec1b06db2bb7   /m/04bcr3   /m/083vt  0.00500  0.033125  0.580000
# 1  82d16a22f703df5c  /m/04dr76w  /m/02gy9n  0.61200  0.735000  0.418919
# 2  b54d41beabcfd900   /m/01mzpv   /m/083vt  0.37250  0.399375  0.706413
# 3  4b6a08cc110d7275   /m/01mzpv  /m/01y9k5  0.17125  0.255625  0.557500
# 4  0144cfbb726f4c72   /m/01mzpv  /m/04bcr3  0.85500  0.950000  0.561667
#
#       YMax1    XMin2     XMax2     YMin2     YMax2 RelationshipLabel
# 0  0.627778  0.00500  0.033125  0.580000  0.627778                is
# 1  0.950450  0.61200  0.735000  0.418919  0.950450                is
# 2  0.778557  0.37250  0.399375  0.706413  0.778557                is
# 3  0.749167  0.20750  0.683125  0.611667  0.999167                at
# 4  0.609167  0.82875  0.999375  0.568333  0.673333                at

# %%
annot_bbox=pd.read_csv('../Data/train-annotations-bbox.csv')
annot_bbox.head()
# Out:
#             ImageID  Source  LabelName  Confidence      XMin      XMax  \
# 0  000002b66c9c498e  xclick  /m/01g317           1  0.012500  0.195312
# 1  000002b66c9c498e  xclick  /m/01g317           1  0.025000  0.276563
# 2  000002b66c9c498e  xclick  /m/01g317           1  0.151562  0.310937
# 3  000002b66c9c498e  xclick  /m/01g317           1  0.256250  0.429688
# 4  000002b66c9c498e  xclick  /m/01g317           1  0.257812  0.346875
#
#        YMin      YMax  IsOccluded  IsTruncated  IsGroupOf  IsDepiction  \
# 0  0.148438  0.587500           0            1          0            0
# 1  0.714063  0.948438           0            1          0            0
# 2  0.198437  0.590625           1            0          0            0
# 3  0.651563  0.925000           1            0          0            0
# 4  0.235938  0.385938           1            0          0            0
#
#    IsInside
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0

# %%
boxes=pd.read_csv('../Data/train-images-boxable-with-rotation.csv')
boxes.head()
# Out:
#             ImageID Subset                                        OriginalURL  \
# 0  4fa8054781a4c382  train  https://farm3.staticflickr.com/5310/5898076654...
# 1  b37f763ae67d0888  train  https://c1.staticflickr.com/1/67/197493648_628...
# 2  7e8584b0f487cb9e  train  https://c7.staticflickr.com/8/7056/7143870979_...
# 3  86638230febe21c4  train  https://farm5.staticflickr.com/5128/5301868579...
# 4  249086e72671397d  train  https://c6.staticflickr.com/4/3930/15342460029...
#
#                                   OriginalLandingURL  \
# 0  https://www.flickr.com/photos/michael-beat/589...
# 1  https://www.flickr.com/photos/drstarbuck/19749...
# 2  https://www.flickr.com/photos/circasassy/71438...
# 3  https://www.flickr.com/photos/ajcreencia/53018...
# 4  https://www.flickr.com/photos/codnewsroom/1534...
#
#                                         License  \
# 0  https://creativecommons.org/licenses/by/2.0/
# 1  https://creativecommons.org/licenses/by/2.0/
# ...

# %%
feature_name=pd.read_csv('../Data/train-annotations-human-imagelabels-boxable.csv')
feature_name.head()
# Out:
#             ImageID        Source  LabelName  Confidence
# 0  000002b66c9c498e  verification  /m/014j1m           0
# 1  000002b66c9c498e  verification  /m/014sv8           1
# 2  000002b66c9c498e  verification   /m/01599           0
# 3  000002b66c9c498e  verification   /m/015p6           0
# 4  000002b66c9c498e  verification  /m/015x4r           0

# %%
df=pd.read_csv('../Data/open-images-dataset-train0.tsv', sep='\t')
df.head()
# Out:
#                                                                      TsvHttpData-1.0
# https://c7.staticflickr.com/6/5499/10245691204_... 141489   XKWUMkcNib71Ge6Yq1/0/g==
# https://farm1.staticflickr.com/5615/15335861457... 7054258  CyvuYIfw90WAr8y0a1PaOw==
# https://c7.staticflickr.com/8/7590/17048042861_... 812483   cFlLPftwE0e7PznqGLwxKA==
# https://farm5.staticflickr.com/5582/18233009494... 1282717  bIoO16vdUB8MpG+Wbe1bxw==
# https://farm6.staticflickr.com/4126/5145819744_... 3129329  nauUgLObUcXqCUxuVabxbw==

# %%
df.shape
# Out:
# (1000000, 1)

# %%
#fonction pour generer la base de donnes
def generate_database(folder_img = "images"):
    database = {}
    for the_file in os.listdir(folder_img):
        file_path = os.path.join(folder_img, the_file)
        try:
            if os.path.isfile(file_path):
               name = the_file.split(".")[0]
               img = cv2.imread(file_path)
               crpim, srcimg, (x, y, w, h) = auto_crop_image(img)
               vector_image = crpim[None,...]
               database[name] = featuremodel.predict(vector_image)[0,:]
        except Exception as e:
            print(e)
    return database
